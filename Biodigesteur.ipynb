# %% [raw]
# ---
# title: MethaConcept
# description: Définir la pertinence technique et éconmique d'une méthanisation domestique.
# show-code: False
# params:
#     filename:
#         label: Fichier des données d'entrées
#         input: file
#         maxFileSize: 5MB
# ---

# %% [markdown]
# # Dimensionnez votre biodigesteur domestique
#
# Ce document est régi par les termes de la licence juridique [Creative Commons CC-BY-SA 4.0](https://creativecommons.org/licenses/by-sa/4.0/deed.fr)
#
# ---
#
# Ce document est rataché au fichier intitulé : **MethaConcept.xlsx** [Lien de téléchargement WEB](https://konsilion.fr/wp/wp-content/uploads/2022/07/MetaConcept.xlsx)
#
# ---

# %%
# Import des donnees calc

import pandas as pd
import numpy as np

# %%
filename = r'MetaConcept.xlsx'

# %%
# pd.set_option('display.float_format', '{:.1f}'.format)

def variable_creation(filepath):
    
    # Lecture du tableau export_data du fichier filename.
    df = pd.read_excel(filepath, sheet_name="export_data",
                             engine="openpyxl").dropna(how='all')
    df = df.to_numpy()
    
    # Initialisation tableau des variables à importer dans Jupyter.
    dfi = [0]*(df.shape[0])
    for i in range(0,df.shape[0]):

        # Routine pour extraire et enregistrer les valeurs depuis le fichier Excel/Ods
        name_sheet = df[i][2]
        col_use = df[i][3]
        skip_r = df[i][4]-1
        n_row = df[i][5]   
        # Extraction et création de la variable i du tableur --> python (numpy)
        dfi[i] = pd.read_excel(filepath, 
                  sheet_name = name_sheet, 
                  skiprows = skip_r,  
                  nrows= n_row, 
                  usecols = col_use,
                  engine="openpyxl").dropna(how='all')
        dfi[i] = dfi[i].replace(np.nan, '', regex=True)
        globals()[df[i][0]]=dfi[i].round(decimals = 4) 
        
variable_creation(filename)

def pd_df_mef(df,nb_round):
           
    styler = df.style.hide(axis='index')\
    .set_properties(subset=[df.columns[0]],
                    **{'font-weight': '', 'background-color': 'white', 'color': ''})\
    .set_caption('')\
    .format(precision=nb_round)
    
    return styler

# %% [markdown]
# ## Les intrants
#
# Nous vous présentons ici les différents intrants que vous avez selectionné ainsi que leurs caractéristiques :

# %%
pd_df_mef(tab_intrant,2)
# Out:
# <style type="text/css">
# #T_e12a3_row0_col0, #T_e12a3_row1_col0, #T_e12a3_row2_col0 {
#   font-weight: ;
#   background-color: white;
#   color: ;
# }
# </style>
# <table id="T_e12a3">
#   <thead>
#     <tr>
#       <th id="T_e12a3_level0_col0" class="col_heading level0 col0" >Designation intrant</th>
#       <th id="T_e12a3_level0_col1" class="col_heading level0 col1" >Quantité</th>
#       <th id="T_e12a3_level0_col2" class="col_heading level0 col2" >%MS</th>
#       <th id="T_e12a3_level0_col3" class="col_heading level0 col3" >%MO</th>
#       <th id="T_e12a3_level0_col4" class="col_heading level0 col4" >%CH4</th>
#       <th id="T_e12a3_level0_col5" class="col_heading level0 col5" >Nm3 CH4 / tMO</th>
#       <th id="T_e12a3_level0_col6" class="col_heading level0 col6" >Chaleur spécifique</th>
#       <th id="T_e12a3_level0_col7" class="col_heading level0 col7" >%H2O</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e12a3_row0_col0" class="data row0 col0" >Dejection humaine</td>
#       <td id="T_e12a3_row0_col1" class="data row0 col1" >300</td>
#       <td id="T_e12a3_row0_col2" class="data row0 col2" >22</td>
#       <td id="T_e12a3_row0_col3" class="data row0 col3" >85</td>
#       <td id="T_e12a3_row0_col4" class="data row0 col4" >55</td>
#       <td id="T_e12a3_row0_col5" class="data row0 col5" >220</td>
#       <td id="T_e12a3_row0_col6" class="data row0 col6" >3300</td>
#       <td id="T_e12a3_row0_col7" class="data row0 col7" >6</td>
#     </tr>
#     <tr>
#       <td id="T_e12a3_row1_col0" class="data row1 col0" >Epluchure</td>
#       <td id="T_e12a3_row1_col1" class="data row1 col1" >146</td>
#       <td id="T_e12a3_row1_col2" class="data row1 col2" >22</td>
#       <td id="T_e12a3_row1_col3" class="data row1 col3" >85</td>
#       <td id="T_e12a3_row1_col4" class="data row1 col4" >55</td>
#       <td id="T_e12a3_row1_col5" class="data row1 col5" >220</td>
#       <td id="T_e12a3_row1_col6" class="data row1 col6" >3300</td>
#       <td id="T_e12a3_row1_col7" class="data row1 col7" >6</td>
#     </tr>
#     <tr>
#       <td id="T_e12a3_row2_col0" class="data row2 col0" >Eaux usées</td>
#       <td id="T_e12a3_row2_col1" class="data row2 col1" >446</td>
#       <td id="T_e12a3_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_e12a3_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_e12a3_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_e12a3_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_e12a3_row2_col6" class="data row2 col6" >4180</td>
#       <td id="T_e12a3_row2_col7" class="data row2 col7" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Les informations digesteurs
#
# Retrouvez ici les informations propres aux digesteurs :

# %%
pd_df_mef(info_dig,2)
# Out:
# <style type="text/css">
# #T_6bd46_row0_col0, #T_6bd46_row1_col0, #T_6bd46_row2_col0, #T_6bd46_row3_col0, #T_6bd46_row4_col0, #T_6bd46_row5_col0, #T_6bd46_row6_col0, #T_6bd46_row7_col0, #T_6bd46_row8_col0, #T_6bd46_row9_col0, #T_6bd46_row10_col0, #T_6bd46_row11_col0, #T_6bd46_row12_col0, #T_6bd46_row13_col0, #T_6bd46_row14_col0, #T_6bd46_row15_col0, #T_6bd46_row16_col0, #T_6bd46_row17_col0, #T_6bd46_row18_col0, #T_6bd46_row19_col0, #T_6bd46_row20_col0, #T_6bd46_row21_col0, #T_6bd46_row22_col0, #T_6bd46_row23_col0, #T_6bd46_row24_col0, #T_6bd46_row25_col0 {
#   font-weight: ;
#   background-color: white;
#   color: ;
# }
# </style>
# <table id="T_6bd46">
#   <thead>
#     <tr>
#       <th id="T_6bd46_level0_col0" class="col_heading level0 col0" >Informations</th>
#       <th id="T_6bd46_level0_col1" class="col_heading level0 col1" > </th>
#       <th id="T_6bd46_level0_col2" class="col_heading level0 col2" >Valeur</th>
#       <th id="T_6bd46_level0_col3" class="col_heading level0 col3" >Unité</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6bd46_row0_col0" class="data row0 col0" >Diamètre</td>
#       <td id="T_6bd46_row0_col1" class="data row0 col1" ></td>
#       <td id="T_6bd46_row0_col2" class="data row0 col2" >70.00</td>
#       <td id="T_6bd46_row0_col3" class="data row0 col3" >cm</td>
#     </tr>
#     <tr>
#       <td id="T_6bd46_row1_col0" class="data row1 col0" >Hauteur</td>
#       <td id="T_6bd46_row1_col1" class="data row1 col1" ></td>
#       <td id="T_6bd46_row1_col2" class="data row1 col2" >70.00</td>
#       <td id="T_6bd46_row1_col3" class="data row1 col3" >cm</td>
#     </tr>
#     <tr>
#       <td id="T_6bd46_row2_col0" class="data row2 col0" >Stockage biogaz % du volume de digestion</td>
#       <td id="T_6bd46_row2_col1" class="data row2 col1" ></td>
#       <td id="T_6bd46_row2_col2" class="data row2 col2" >10.00</td>
#       <td id="T_6bd46_row2_col3" class="data row2 col3" >%</td>
#     </tr>
#     <tr>
#       <td id="T_6bd46_row3_col0" class="data row3 col0" >Production attendues % du BMP max</td>
#       <td id="T_6bd46_row3_col1" class="data row3 col1" ></td>
#       <td id="T_6bd46_row3_col2" class="data row3 col2" >1.00</td>
#       <td id="T_6bd46_row3_col3" class="data row3 col3" >%</td>
#     </tr>
#     <tr>
#       <td id="T_6bd46_row4_col0" class="data row4 col0" >Température digestion</td>
#       <td id="T_6bd46_row4_col1" class="data row4 col1" ></td>
#       <td id="T_6bd46_row4_col2" class="data row4 col2" >30.00</td>
#       <td id="T_6bd46_row4_col3" class="data row4 col3" >°C</td>
#     </tr>
#     <tr>
#       <td id="T_6bd46_row5_col0" class="data row5 col0" >Température ciel gazeux</td>
#       <td id="T_6bd46_row5_col1" class="data row5 col1" ></td>
#       <td id="T_6bd46_row5_col2" class="data row5 col2" >30.00</td>
#       <td id="T_6bd46_row5_col3" class="data row5 col3" >°C</td>
#     </tr>
#     <tr>
#       <td id="T_6bd46_row6_col0" class="data row6 col0" >Nombre d'heure de chauffe</td>
#       <td id="T_6bd46_row6_col1" class="data row6 col1" ></td>
#       <td id="T_6bd46_row6_col2" class="data row6 col2" >24.00</td>
#       <td id="T_6bd46_row6_col3" class="data row6 col3" >h</td>
#     </tr>
#     <tr>
#       <td id="T_6bd46_row7_col0" class="data row7 col0" >Epaisseur paroi</td>
#       <td id="T_6bd46_row7_col1" class="data row7 col1" >Toiture</td>
#       <td id="T_6bd46_row7_col2" class="data row7 col2" >0.50</td>
#       <td id="T_6bd46_row7_col3" class="data row7 col3" >cm</td>
#     </tr>
#     <tr>
#       <td id="T_6bd46_row8_col0" class="data row8 col0" ></td>
#       <td id="T_6bd46_row8_col1" class="data row8 col1" >Mur</td>
#       <td id="T_6bd46_row8_col2" class="data row8 col2" >0.50</td>
#       <td id="T_6bd46_row8_col3" class="data row8 col3" >cm</td>
#     </tr>
#     <tr>
#       <td id="T_6bd46_row9_col0" class="data row9 col0" ></td>
#       <td id="T_6bd46_row9_col1" class="data row9 col1" >Sol</td>
#       <td id="T_6bd46_row9_col2" class="data row9 col2" >0.50</td>
#       <td id="T_6bd46_row9_col3" class="data row9 col3" >cm</td>
#     </tr>
#     <tr>
#       <td id="T_6bd46_row10_col0" class="data row10 col0" >Conductivité paroi</td>
#       <td id="T_6bd46_row10_col1" class="data row10 col1" ></td>
#       <td id="T_6bd46_row10_col2" class="data row10 col2" >0.17</td>
#       <td id="T_6bd46_row10_col3" class="data row10 col3" >W/(m/K)</td>
#     </tr>
#     <tr>
#       <td id="T_6bd46_row11_col0" class="data row11 col0" >Epaisseur isolant</td>
#       <td id="T_6bd46_row11_col1" class="data row11 col1" >Toiture</td>
#       <td id="T_6bd46_row11_col2" class="data row11 col2" >5.00</td>
#       <td id="T_6bd46_row11_col3" class="data row11 col3" >cm</td>
#     </tr>
#     <tr>
#       <td id="T_6bd46_row12_col0" class="data row12 col0" ></td>
#       <td id="T_6bd46_row12_col1" class="data row12 col1" >Mur</td>
#       <td id="T_6bd46_row12_col2" class="data row12 col2" >15.00</td>
#       <td id="T_6bd46_row12_col3" class="data row12 col3" >cm</td>
#     </tr>
#     <tr>
#       <td id="T_6bd46_row13_col0" class="data row13 col0" ></td>
#       <td id="T_6bd46_row13_col1" class="data row13 col1" >Sol</td>
#       <td id="T_6bd46_row13_col2" class="data row13 col2" >15.00</td>
#       <td id="T_6bd46_row13_col3" class="data row13 col3" >cm</td>
#     </tr>
#     <tr>
#       <td id="T_6bd46_row14_col0" class="data row14 col0" >Conductivité isolant</td>
#       <td id="T_6bd46_row14_col1" class="data row14 col1" ></td>
#       <td id="T_6bd46_row14_col2" class="data row14 col2" >0.04</td>
#       <td id="T_6bd46_row14_col3" class="data row14 col3" >W/(m/K)</td>
#     </tr>
#     <tr>
#       <td id="T_6bd46_row15_col0" class="data row15 col0" >Hauteur totale</td>
#       <td id="T_6bd46_row15_col1" class="data row15 col1" ></td>
#       <td id="T_6bd46_row15_col2" class="data row15 col2" >77.00</td>
#       <td id="T_6bd46_row15_col3" class="data row15 col3" >cm</td>
#     </tr>
#     <tr>
#       <td id="T_6bd46_row16_col0" class="data row16 col0" >Volume de digestion total</td>
#       <td id="T_6bd46_row16_col1" class="data row16 col1" ></td>
#       <td id="T_6bd46_row16_col2" class="data row16 col2" >0.27</td>
#       <td id="T_6bd46_row16_col3" class="data row16 col3" >m3</td>
#     </tr>
#     <tr>
#       <td id="T_6bd46_row17_col0" class="data row17 col0" >Volume de stockage biogaz</td>
#       <td id="T_6bd46_row17_col1" class="data row17 col1" ></td>
#       <td id="T_6bd46_row17_col2" class="data row17 col2" >0.03</td>
#       <td id="T_6bd46_row17_col3" class="data row17 col3" >m3</td>
#     </tr>
#     <tr>
#       <td id="T_6bd46_row18_col0" class="data row18 col0" >Surface sol</td>
#       <td id="T_6bd46_row18_col1" class="data row18 col1" ></td>
#       <td id="T_6bd46_row18_col2" class="data row18 col2" >0.38</td>
#       <td id="T_6bd46_row18_col3" class="data row18 col3" >m²</td>
#     </tr>
#     <tr>
#       <td id="T_6bd46_row19_col0" class="data row19 col0" >Surface mur-air</td>
#       <td id="T_6bd46_row19_col1" class="data row19 col1" ></td>
#       <td id="T_6bd46_row19_col2" class="data row19 col2" >1.69</td>
#       <td id="T_6bd46_row19_col3" class="data row19 col3" >m²</td>
#     </tr>
#     <tr>
#       <td id="T_6bd46_row20_col0" class="data row20 col0" >Surface toiture</td>
#       <td id="T_6bd46_row20_col1" class="data row20 col1" ></td>
#       <td id="T_6bd46_row20_col2" class="data row20 col2" >0.38</td>
#       <td id="T_6bd46_row20_col3" class="data row20 col3" >m²</td>
#     </tr>
#     <tr>
#       <td id="T_6bd46_row21_col0" class="data row21 col0" >Resistance thermique sol</td>
#       <td id="T_6bd46_row21_col1" class="data row21 col1" ></td>
#       <td id="T_6bd46_row21_col2" class="data row21 col2" >1.28</td>
#       <td id="T_6bd46_row21_col3" class="data row21 col3" >m².K/W</td>
#     </tr>
#     <tr>
#       <td id="T_6bd46_row22_col0" class="data row22 col0" >Resistance thermique mur</td>
#       <td id="T_6bd46_row22_col1" class="data row22 col1" ></td>
#       <td id="T_6bd46_row22_col2" class="data row22 col2" >1.28</td>
#       <td id="T_6bd46_row22_col3" class="data row22 col3" >m².K/W</td>
#     </tr>
#     <tr>
#       <td id="T_6bd46_row23_col0" class="data row23 col0" >Resistanc

# %% [markdown]
# ## Les informations techniques
#
# Ici les informations techniques :

# %%
pd_df_mef(tab_temperature,1)
# Out:
# <style type="text/css">
# #T_13a52_row0_col0, #T_13a52_row1_col0, #T_13a52_row2_col0, #T_13a52_row3_col0, #T_13a52_row4_col0 {
#   font-weight: ;
#   background-color: white;
#   color: ;
# }
# </style>
# <table id="T_13a52">
#   <thead>
#     <tr>
#       <th id="T_13a52_level0_col0" class="col_heading level0 col0" >En °C</th>
#       <th id="T_13a52_level0_col1" class="col_heading level0 col1" >Janvier</th>
#       <th id="T_13a52_level0_col2" class="col_heading level0 col2" >Février</th>
#       <th id="T_13a52_level0_col3" class="col_heading level0 col3" >Mars</th>
#       <th id="T_13a52_level0_col4" class="col_heading level0 col4" >Avril</th>
#       <th id="T_13a52_level0_col5" class="col_heading level0 col5" >Mai</th>
#       <th id="T_13a52_level0_col6" class="col_heading level0 col6" >Juin</th>
#       <th id="T_13a52_level0_col7" class="col_heading level0 col7" >Juillet</th>
#       <th id="T_13a52_level0_col8" class="col_heading level0 col8" >Août</th>
#       <th id="T_13a52_level0_col9" class="col_heading level0 col9" >Septembre</th>
#       <th id="T_13a52_level0_col10" class="col_heading level0 col10" >Octobre</th>
#       <th id="T_13a52_level0_col11" class="col_heading level0 col11" >Novembre</th>
#       <th id="T_13a52_level0_col12" class="col_heading level0 col12" >Décembre</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_13a52_row0_col0" class="data row0 col0" >Temperature à 2m</td>
#       <td id="T_13a52_row0_col1" class="data row0 col1" >5.6</td>
#       <td id="T_13a52_row0_col2" class="data row0 col2" >5.3</td>
#       <td id="T_13a52_row0_col3" class="data row0 col3" >6.5</td>
#       <td id="T_13a52_row0_col4" class="data row0 col4" >9.7</td>
#       <td id="T_13a52_row0_col5" class="data row0 col5" >13.5</td>
#       <td id="T_13a52_row0_col6" class="data row0 col6" >18.3</td>
#       <td id="T_13a52_row0_col7" class="data row0 col7" >21.6</td>
#       <td id="T_13a52_row0_col8" class="data row0 col8" >21.3</td>
#       <td id="T_13a52_row0_col9" class="data row0 col9" >18.5</td>
#       <td id="T_13a52_row0_col10" class="data row0 col10" >11.5</td>
#       <td id="T_13a52_row0_col11" class="data row0 col11" >7.7</td>
#       <td id="T_13a52_row0_col12" class="data row0 col12" >5.2</td>
#     </tr>
#     <tr>
#       <td id="T_13a52_row1_col0" class="data row1 col0" >Temperature sous-sol</td>
#       <td id="T_13a52_row1_col1" class="data row1 col1" >15.6</td>
#       <td id="T_13a52_row1_col2" class="data row1 col2" >15.3</td>
#       <td id="T_13a52_row1_col3" class="data row1 col3" >16.5</td>
#       <td id="T_13a52_row1_col4" class="data row1 col4" >19.7</td>
#       <td id="T_13a52_row1_col5" class="data row1 col5" >19.7</td>
#       <td id="T_13a52_row1_col6" class="data row1 col6" >19.7</td>
#       <td id="T_13a52_row1_col7" class="data row1 col7" >19.7</td>
#       <td id="T_13a52_row1_col8" class="data row1 col8" >19.7</td>
#       <td id="T_13a52_row1_col9" class="data row1 col9" >19.7</td>
#       <td id="T_13a52_row1_col10" class="data row1 col10" >19.7</td>
#       <td id="T_13a52_row1_col11" class="data row1 col11" >17.7</td>
#       <td id="T_13a52_row1_col12" class="data row1 col12" >15.2</td>
#     </tr>
#     <tr>
#       <td id="T_13a52_row2_col0" class="data row2 col0" >Dejection humaine</td>
#       <td id="T_13a52_row2_col1" class="data row2 col1" >3.6</td>
#       <td id="T_13a52_row2_col2" class="data row2 col2" >3.3</td>
#       <td id="T_13a52_row2_col3" class="data row2 col3" >4.5</td>
#       <td id="T_13a52_row2_col4" class="data row2 col4" >7.7</td>
#       <td id="T_13a52_row2_col5" class="data row2 col5" >11.5</td>
#       <td id="T_13a52_row2_col6" class="data row2 col6" >17.0</td>
#       <td id="T_13a52_row2_col7" class="data row2 col7" >17.0</td>
#       <td id="T_13a52_row2_col8" class="data row2 col8" >3.6</td>
#       <td id="T_13a52_row2_col9" class="data row2 col9" >3.3</td>
#       <td id="T_13a52_row2_col10" class="data row2 col10" >4.5</td>
#       <td id="T_13a52_row2_col11" class="data row2 col11" >7.7</td>
#       <td id="T_13a52_row2_col12" class="data row2 col12" >11.5</td>
#     </tr>
#     <tr>
#       <td id="T_13a52_row3_col0" class="data row3 col0" >Epluchure</td>
#       <td id="T_13a52_row3_col1" class="data row3 col1" >3.6</td>
#       <td id="T_13a52_row3_col2" class="data row3 col2" >3.3</td>
#       <td id="T_13a52_row3_col3" class="data row3 col3" >4.5</td>
#       <td id="T_13a52_row3_col4" class="data row3 col4" >7.7</td>
#       <td id="T_13a52_row3_col5" class="data row3 col5" >11.5</td>
#       <td id="T_13a52_row3_col6" class="data row3 col6" >17.0</td>
#       <td id="T_13a52_row3_col7" class="data row3 col7" >17.0</td>
#       <td id="T_13a52_row3_col8" class="data row3 col8" >3.6</td>
#       <td id="T_13a52_row3_col9" class="data row3 col9" >3.3</td>
#       <td id="T_13a52_row3_col10" class="data row3 col10" >4.5</td>
#       <td id="T_13a52_row3_col11" class="data row3 col11" >7.7</td>
#       <td id="T_13a52_row3_col12" class="data row3 col12" >11.5</td>
#     </tr>
#     <tr>
#       <td id="T_13a52_row4_col0" class="data row4 col0" >Eaux usées</td>
#       <td id="T_13a52_row4_col1" class="data row4 col1" >3.6</td>
#       <td id="T_13a52_row4_col2" class="data row4 col2" >3.3</td>
#       <td id="T_13a52_row4_col3" class="data row4 col3" >4.5</td>
#       <td id="T_13a52_row4_col4" class="data row4 col4" >7.7</td>
#       <td id="T_13a52_row4_col5" class="data row4 col5" >11.5</td>
#       <td id="T_13a52_row4_col6" class="data row4 col6" >17.0</td>
#       <td id="T_13a52_row4_col7" class="data row4 col7" >17.0</td>
#       <td id="T_13a52_row4_col8" class="data row4 col8" >3.6</td>
#       <td id="T_13a52_row4_col9" class="data row4 col9" >3.3</td>
#       <td id="T_13a52_row4_col10" class="data row4 col10" >4.5</td>
#       <td id="T_13a52_row4_col11" class="data row4 col11" >7.7</td>
#       <td id="T_13a52_row4_col12" class="data row4 col12" >11.5</td>
#     </tr>
#   </tbody>
# </table>
